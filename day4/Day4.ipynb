# %%
import pandas as pd
from functools import reduce

# %%
# DAY 4 - PART 1

def lines2Passports(lines):
    pps = []
    pp = {}
    for l in lines:
        if l == '':
            pps += [pp]
            pp = {}
        else:
            kvs = [att.split(':') for att in l.split(' ')]
            for kv in kvs:
                pp[kv[0]] = kv[1]
    pps += [pp]
    pp = {}
    
    return pps

with open('input', 'r') as f:
    lines = [l.replace('\n', '') for l in f.readlines()]
    passports = lines2Passports(lines)

#byr (Birth Year)
#iyr (Issue Year)
#eyr (Expiration Year)
#hgt (Height)
#hcl (Hair Color)
#ecl (Eye Color)
#pid (Passport ID)
#cid (Country ID)

requiredFields = ['byr', 'iyr', 'eyr', 'hgt', 'hcl', 'ecl', 'pid']
# print(f'Input passports: {passports}')
print(f'Num input passports: {len(passports)}')

validPassportsPart1 = [p for p in passports if all([field in p for field in requiredFields])]
print(f'Num valid passports: {len(validPassportsPart1)}')
# Out:
# Num input passports: 286
# Num valid passports: 254

# %%
# DAY 4 - PART 2

import re

def validateByr(s, reg=re.compile('^(?P<year>\d{4})$')):
    m = reg.match(s)
    if m:
        valid = 'year' in m.groupdict() and int(m.groupdict()['year']) >= 1920 and int(m.groupdict()['year']) <= 2002
        if not valid:
            error['byr'].append(s)
            print(f'Invalid BYR: {s}')
        return valid
    else:
        print(f'(-) no BYR {s}')
        return False

def validateIyr(s, reg=re.compile('^(?P<year>\d{4})$')):
    m = reg.match(s)
    if m:
        valid = 'year' in m.groupdict() and int(m.groupdict()['year']) >= 2010 and int(m.groupdict()['year']) <= 2020
        if not valid:
            error['iyr'].append(s)
            print(f'Invalid IYR: {s}')
        return valid
    else:
        print(f'(-) no IYR {s}')
        return False
    
def validateEyr(s, reg=re.compile('^(?P<year>\d{4})$')):
    m = reg.match(s)
    if m:
        valid = 'year' in m.groupdict() and int(m.groupdict()['year']) >= 2020 and int(m.groupdict()['year']) <= 2030
        if not valid:
            error['eyr'].append(s)
            print(f'Invalid EYR: {s}')
        return valid
    else:
        print(f'(-) no EYR {s}')
        return False
    
def validateHgt(s, reg=re.compile('^(?P<height>\d+)(?P<unit>cm|in)$')):
    m = reg.match(s)
    if m:
        h = int(m.groupdict()['height'])
        u = m.group("unit")
        
        valid = 'height' in m.groupdict() and 'unit' in m.groupdict() and \
            ((u == 'cm' and h >= 150 and h <= 193) or (u == 'in' and h >= 59 and h <= 76))
        if not valid:
            error['hgt'].append(s)
            print(f'Invalid height: {h} {u}')
            
        return valid
    else:
        print(f'(-) no height or no unit "{s}"')
        return False
    
def validateHcl(s, reg=re.compile('^(?P<haircolor>#[\da-fA-F]{6})')):
    m = reg.match(s)
    if m:
        #print(f'Haircolor: {m.group("haircolor")}')
        valid = 'haircolor' in m.groupdict()
        if not valid:
            error['hcl'].append(s)
            print(f'Invalid Haircolor: {s}')
        return valid
    else:
        print(f'(-) no haircolor found in {s}')
        return False
    
def validateEcl(s, reg=re.compile('(?P<eyecolor>amb|blu|brn|gry|grn|hzl|oth)')):
    m = reg.match(s)
    if m:
        #print(f'Eye color: {m.group("eyecolor")}')
        valid = 'eyecolor' in m.groupdict()
        if not valid:
            error['ecl'].append(s)
            print(f'Invalid Eyecolor: {s}')
        return valid
    else:
        print(f'(-) no eyecolor found {s}')
        return False
    
def validatePid(s, reg=re.compile('^(?P<pid>\d{9})$')):
    m = reg.match(s)
    if m:
        #print(f'pid: {m.group("pid")}')
        valid = 'pid' in m.groupdict()
        if not valid:
            error['pid'].append(s)
            print(f'Invalid pid: {s}')
        else:
            print(f'(+) valid pid: "{s}"')
        return valid
    
    else:
        print(f'(-) no pid found {s}')
        return False
    
def validateCid(s):
    return True

validators = {
    'byr': validateByr,
    'iyr': validateIyr,
    'eyr': validateEyr,
    'hgt': validateHgt,
    'hcl': validateHcl,
    'ecl': validateEcl,
    'pid': validatePid,
    'cid': validateCid
}

error = {
    'byr': [],
    'iyr': [],
    'eyr': [],
    'hgt': [],
    'hcl': [],
    'ecl': [],
    'pid': [],
    'cid': []
}

def isValid(pp, validators=validators):
    return [validators[key](value) for (key, value) in list(pp.items())]

validPassportsPart2 = [isValid(p) for p in validPassportsPart1]
#print(f'valid passports: {validPassportsPart2}')
print(f'ERRORS')
for k,vl in error.items():
    print(f'{k}: {vl}')
    print("\n\t".join(sorted(vl)))
print(f'Num valid passports Part2: {len([p for p in validPassportsPart2 if all(p)])}')
# Out:
# (+) valid pid: "591597745"
# (+) valid pid: "404183620"
# (+) valid pid: "594143498"
# (+) valid pid: "364060467"
# (+) valid pid: "374679609"
# (+) valid pid: "579769934"
# (+) valid pid: "817651329"
# (+) valid pid: "648375525"
# (+) valid pid: "770851101"
# (+) valid pid: "116783406"
# (+) valid pid: "257797292"
# Invalid IYR: 2026
# Invalid BYR: 2024
# (-) no haircolor found in a22966
# (-) no pid found 155cm
# (+) valid pid: "081232570"
# (+) valid pid: "600039004"
# (+) valid pid: "021066381"
# (+) valid pid: "358390884"
# (+) valid pid: "607203641"
# (+) valid pid: "649263319"
# (+) valid pid: "147939289"
# (+) valid pid: "686943691"
# (+) valid pid: "568844323"
# Invalid IYR: 1937
# (+) valid pid: "686240814"
# (-) no eyecolor found #a8ba32
# (+) valid pid: "543383899"
# (+) valid pid: "196374590"
# (+) valid pid: "593027548"
# (+) valid pid: "588211492"
# Invalid IYR: 2021
# (-) no haircolor found in z
# (+) valid pid: "490291639"
# (+) valid pid: "404157420"
# (+) valid pid: "320691739"
# (+) valid pid: "440489464"
# (+) valid pid: "062728732"
# (+) valid pid: "000647617"
# (+) valid pid: "459190453"
# (+) valid pid: "630408328"
# (+) valid pid: "752776254"
# (+) valid pid: "504471386"
# (-) no height or no unit "84"
# (-) no pid found 168cm
# (-) no haircolor found in 8532fb
# (-) no eyecolor found xry
# Invalid BYR: 2008
# (+) valid pid: "495737304"
# (+) valid pid: "546906638"
# (+) valid pid: "839249028"
# (-) no haircolor found in z
# Invalid BYR: 2024
# (-) no height or no unit "145"
# Invalid EYR: 2034
# Invalid IYR: 2021
# (-) no eyecolor found #891c47
# Invalid EYR: 2036
# (-) no eyecolor found #89d2ae
# Invalid BYR: 2014
# (-) no haircolor found in b3af0f
# (-) no pid found 12086913
# Invalid IYR: 1981
# Invalid height: 61 cm
# (+) valid pid: "083487445"
# (-) no haircolor found in z
# Invalid IYR: 2021
# (-) no height or no unit "182"
# (+) valid pid: "704026565"
# (+) valid pid: "694575319"
# (+) valid pid: "269157261"
# (+) valid pid: "904779190"
# (+) valid pid: "402585706"
# (+) valid pid: "083364259"
# (+) valid pid: "521514539"
# (-) no haircolor found in dc0449
# Invalid EYR: 1981
# (-) no pid found 188cm
# Invalid IYR: 1979
# Invalid height: 61 cm
# (-) no eyecolor found dne
# Invalid BYR: 2028
# (+) valid pid: "424127124"
# Invalid EYR: 2039
# (+) valid pid: "7837217107"
# (-) no haircolor found in z
# Invalid BYR: 2005
# Invalid IYR: 1989
# (-) no eyecolor found #d95f4d
# Invalid height: 190 in
# (-) no eyecolor found #329eb1
# (-) no height or no unit "192"
# Invalid BYR: 2028
# (+) valid pid: "7175349420"
# (+) valid pid: "653585396"
# (+) valid pid: "388475446"
# (+) valid pid: "253592171"
# Invalid EYR: 2031
# Invalid IYR: 2024
# (-) no pid found 151cm
# (-) no haircolor found in z
# Invalid IYR: 1971
# Invalid height: 192 in
# (+) valid pid: "5479810865"
# (+) valid pid: "136216608"
# (+) valid pid: "488392920"
# (+) valid pid: "731763175"
# (+) valid pid: "617055193"
# (+) valid pid: "257895944"
# (+) valid pid: "438580092"
# (-) no eyecolor found grt
# Invalid BYR: 2025
# (-) no haircolor found in z
# Invalid IYR: 2000
# Invalid EYR: 1952
# Invalid height: 170 in
# (+) valid pid: "409793041"
# (+) valid pid: "563307670"
# (+) valid pid: "329759796"
# (+) valid pid: "459613739"
# (+) valid pid: "385660251"
# (+) valid pid: "087661720"
# (+) valid pid: "448389966"
# (+) valid pid: "088166852"
# (-) no eyecolor found #af542f
# Invalid BYR: 2026
# Invalid EYR: 2039
# (-) no haircolor found in 5449b3
# Invalid height: 176 in
# Invalid IYR: 1962
# (-) no pid found 177cm
# (+) valid pid: "931543453"
# (+) valid pid: "866631112"
# (+) valid pid: "615734013"
# (-) no height or no unit "86"
# Invalid IYR: 1935
# (-) no eyecolor found grt
# (-) no pid found #af8e67
# Invalid EYR: 2031
# Invalid BYR: 2018
# (-) no haircolor found in 6a2940
# (+) valid pid: "077121198"
# (+) valid pid: "311289324"
# (+) valid pid: "827480048"
# (+) valid pid: "127497651"
# Invalid BYR: 2015
# Invalid height: 187 in
# (-) no pid found 82075551
# Invalid EYR: 1936
# Invalid IYR: 1939
# (+) valid pid: "661559147"
# Invalid EYR: 2009
# Invalid BYR: 2028
# Invalid height: 170 in
# (-) no pid found 161cm
# (+) valid pid: "098090405"
# (+) valid pid: "495271053"
# (+) valid pid: "137146932"
# (+) valid pid: "168517472"
# (+) valid pid: "947158470"
# (+) valid pid: "243339529"
# (+) valid pid: "664966826"
# Invalid EYR: 2036
# (-) no haircolor found in z
# (-) no eyecolor found #038105
# (+) valid pid: "870519416"
# (+) valid pid: "827688488"
# (+) valid pid: "124116963"
# (-) no eyecolor found utc
# (-) no pid found #2fd9f2
# (+) valid pid: "588957573"
# (+) valid pid: "668244584"
# Invalid EYR: 1985
# (+) valid pid: "494051052"
# (+) valid pid: "557549000"
# (+) valid pid: "828235468"
# (+) valid pid: "957913612"
# (+) valid pid: "596116320"
# (+) valid pid: "594817909"
# (+) valid pid: "073211525"
# (+) valid pid: "706155322"
# (-) no haircolor found in bcb5f7
# (+) valid pid: "850069752"
# (+) valid pid: "983486664"
# (+) valid pid: "182737852"
# Invalid EYR: 2035
# (-) no eyecolor found xry
# Invalid height: 61 cm
# (-) no haircolor found in ce89a8
# (+) valid pid: "335540582"
# (-) no pid found #05153d
# Invalid IYR: 1990
# Invalid EYR: 1927
# Invalid height: 71 cm
# Invalid BYR: 2019
# (-) no eyecolor found #e38688
# (-) no haircolor found in c6abd9
# (+) valid pid: "976419172"
# (+) valid pid: "706186218"
# (+) valid pid: "382832140"
# (-) no haircolor found in 0b87a1
# Invalid BYR: 2020
# (+) valid pid: "4365879329"
# Invalid EYR: 2032
# (+) valid pid: "876924536"
# (+) valid pid: "997639611"
# (+) valid pid: "808460262"
# Invalid EYR: 2031
# (+) valid pid: "381144425"
# (+) valid pid: "015229624"
# Invalid height: 66 cm
# (-) no haircolor found in z
# (-) no eyecolor found #8b12fb
# (+) valid pid: "283039791"
# (+) valid pid: "798610943"
# Invalid height: 189 in
# (+) valid pid: "041625574"
# (+) valid pid: "279080024"
# (-) no haircolor found in z
# Invalid IYR: 1970
# (-) no pid found #540e31
# (+) valid pid: "269015932"
# (+) valid pid: "050653473"
# (+) valid pid: "650190272"
# (+) valid pid: "615309584"
# (+) valid pid: "244918527"
# (+) valid pid: "337615663"
# (+) valid pid: "033663619"
# (+) valid pid: "100788192"
# (-) no eyecolor found #92b14c
# Invalid IYR: 1940
# Invalid EYR: 2033
# (+) valid pid: "357835141"
# (+) valid pid: "895992818"
# (+) valid pid: "346938111"
# (+) valid pid: "825661608"
# (+) valid pid: "101838832"
# (+) valid pid: "015890498"
# (+) valid pid: "404983369"
# (+) valid pid: "615831236"
# (+) valid pid: "271614109"
# (-) no eyecolor found #e45ee0
# (-) no pid found 151cm
# Invalid BYR: 2022
# (-) no haircolor found in 973bc1
# Invalid EYR: 2033
# Invalid height: 181 in
# (-) no eyecolor found xry
# Invalid BYR: 2023
# Invalid IYR: 1973
# (-) no pid found 4137668
# Invalid EYR: 2037
# (-) no haircolor found in z
# (+) valid pid: "674080319"
# (+) valid pid: "111247018"
# Invalid height: 192 in
# (-) no eyecolor found #8bf268
# Invalid IYR: 2022
# (-) no haircolor found in z
# (-) no pid found #88e8df
# Invalid BYR: 2026
# Invalid EYR: 2032
# (+) valid pid: "788808021"
# Invalid height: 156 in
# Invalid BYR: 2024
# (-) no haircolor found in 4e4dd6
# Invalid IYR: 2028
# (-) no pid found 35683378
# (-) no eyecolor found #3a9fba
# (+) valid pid: "081236370"
# (-) no haircolor found in d15b43
# Invalid BYR: 2029
# (-) no height or no unit "118"
# Invalid IYR: 2026
# Invalid EYR: 2038
# (-) no eyecolor found grt
# Invalid EYR: 2034
# (-) no pid found 186cm
# (-) no eyecolor found utc
# Invalid IYR: 2009
# Invalid BYR: 2018
# (-) no haircolor found in 163913
# Invalid height: 74 cm
# (+) valid pid: "249858519"
# (+) valid pid: "446135799"
# (+) valid pid: "104835585"
# (+) valid pid: "199216567"
# (+) valid pid: "472300557"
# (-) no eyecolor found #2a8a59
# Invalid BYR: 2021
# (+) valid pid: "365979521"
# (-) no haircolor found in z
# (+) valid pid: "363851353"
# (+) valid pid: "443722683"
# (+) valid pid: "934896568"
# (+) valid pid: "524699651"
# (+) valid pid: "739947771"
# (+) valid pid: "681478012"
# (+) valid pid: "807715479"
# Invalid EYR: 1972
# (-) no height or no unit "151"
# (+) valid pid: "635008585"
# (+) valid pid: "550276277"
# (+) valid pid: "125635376"
# (+) valid pid: "042700658"
# (+) valid pid: "447451869"
# (+) valid pid: "614496034"
# (+) valid pid: "128207503"
# (+) valid pid: "317675262"
# (+) valid pid: "077163993"
# Invalid IYR: 2030
# (-) no eyecolor found #faff64
# Invalid BYR: 2012
# (+) valid pid: "734434105"
# Invalid height: 164 in
# (-) no haircolor found in z
# Invalid height: 150 in
# (-) no pid found 173cm
# (-) no haircolor found in db675a
# Invalid EYR: 2032
# (-) no eyecolor found xry
# (+) valid pid: "087437383"
# (-) no pid found 152cm
# Invalid IYR: 2030
# Invalid BYR: 2010
# (-) no haircolor found in z
# (-) no pid found #7356dd
# Invalid BYR: 2005
# (-) no pid found 179cm
# (+) valid pid: "649681621"
# (+) valid pid: "839016251"
# (+) valid pid: "112604496"
# (-) no height or no unit "184"
# (+) valid pid: "952646285"
# (+) valid pid: "455008820"
# (+) valid pid: "081011361"
# Invalid IYR: 1999
# (+) valid pid: "9252198900"
# (+) valid pid: "760213482"
# (+) valid pid: "242381670"
# Invalid BYR: 2021
# (-) no pid found #a94a22
# Invalid IYR: 1969
# (-) no eyecolor found zzz
# Invalid height: 76 cm
# (+) valid pid: "164128658"
# (+) valid pid: "232659795"
# (+) valid pid: "001171231"
# (+) valid pid: "809880438"
# (+) valid pid: "754135833"
# (+) valid pid: "053980893"
# (+) valid pid: "914067457"
# (+) valid pid: "688816242"
# (+) valid pid: "888703414"
# (+) valid pid: "359774824"
# (+) valid pid: "743371399"
# Invalid EYR: 1920
# Invalid BYR: 2010
# (-) no pid found #69d6ba
# (-) no height or no unit "74"
# (-) no haircolor found in z
# (-) no eyecolor found #d256f3
# Invalid IYR: 1933
# (+) valid pid: "435518624"
# (+) valid pid: "024527693"
# Invalid EYR: 1932
# Invalid IYR: 2023
# (+) valid pid: "005741906"
# Invalid IYR: 2029
# (-) no height or no unit "108"
# Invalid BYR: 2029
# (-) no haircolor found in c8b25d
# (+) valid pid: "522512400"
# Invalid EYR: 2038
# (-) no eyecolor found zzz
# (+) valid pid: "371295649"
# (-) no haircolor found in z
# (+) valid pid: "619653661"
# Invalid IYR: 1931
# (+) valid pid: "565552342"
# (-) no eyecolor found #af97bb
# (-) no haircolor found in c92cd6
# Invalid EYR: 1931
# Invalid BYR: 2025
# Invalid height: 184 in
# (+) valid pid: "202254357"
# (+) valid pid: "298693475"
# (-) no eyecolor found dne
# Invalid BYR: 2014
# Invalid IYR: 1951
# Invalid EYR: 2039
# (+) valid pid: "135688013"
# Invalid BYR: 2019
# Invalid EYR: 1971
# (-) no pid found #a95cb4
# (-) no eyecolor found #6f919c
# (+) valid pid: "497726268"
# (+) valid pid: "216607711"
# Invalid EYR: 1931
# (-) no pid found #876b1a
# (-) no eyecolor found #5f0f80
# (+) valid pid: "271136754"
# (+) valid pid: "510020331"
# (+) valid pid: "671943334"
# (+) valid pid: "000803215"
# (+) valid pid: "612432109"
# (+) valid pid: "846986027"
# (-) no pid found 48544569
# (+) valid pid: "857428120"
# (+) valid pid: "559783197"
# (+) valid pid: "724332293"
# Invalid EYR: 2031
# Invalid BYR: 2011
# (+) valid pid: "377875085"
# (+) valid pid: "286225332"
# (-) no height or no unit "85"
# (-) no eyecolor found xry
# Invalid EYR: 2033
# Invalid IYR: 1952
# (-) no pid found 92902290
# (-) no haircolor found in a6f86d
# Invalid BYR: 2013
# (+) valid pid: "368741489"
# (+) valid pid: "718568707"
# Invalid BYR: 2003
# (+) valid pid: "675429853"
# (+) valid pid: "080846464"
# (+) valid pid: "1756319674"
# Invalid EYR: 2035
# (-) no haircolor found in z
# Invalid height: 61 cm
# (+) valid pid: "3267812127"
# Invalid BYR: 2029
# Invalid IYR: 2028
# (-) no eyecolor found lzr
# (+) valid pid: "354474868"
# (+) valid pid: "727482965"
# (+) valid pid: "040800697"
# Invalid IYR: 2030
# (+) valid pid: "752644096"
# (+) valid pid: "054367702"
# (+) valid pid: "189859171"
# (+) valid pid: "650970816"
# (+) valid pid: "868785851"
# Invalid EYR: 2040
# Invalid BYR: 2030
# (-) no haircolor found in afde59
# (-) no pid found 72468598
# Invalid IYR: 1990
# (-) no eyecolor found #896a8e
# Invalid IYR: 2009
# (+) valid pid: "844037301"
# (+) valid pid: "755280305"
# (+) valid pid: "059284139"
# (+) valid pid: "083241291"
# (+) valid pid: "076848285"
# (+) valid pid: "681067688"
# Invalid IYR: 1972
# (-) no pid found 21811501
# (-) no eyecolor found #17c6e8
# Invalid height: 158 in
# Invalid BYR: 2015
# (-) no haircolor found in 5b7956
# (+) valid pid: "097863725"
# (-) no eyecolor found #a0eeca
# (+) valid pid: "724783488"
# (-) no height or no unit "124"
# Invalid BYR: 2012
# Invalid EYR: 2036
# (-) no haircolor found in z
# (-) no height or no unit "97"
# (-) no pid found #677847
# (-) no eyecolor found dne
# (+) valid pid: "341708492"
# (+) valid pid: "701862616"
# ERRORS
# byr: ['2024', '2008', '2024', '2014', '2028', '2005', '2028', '2025', '2026', '2018', '2015', '2028', '2019', '2020', '2022', '2023', '2026', '2024', '2029', '2018', '2021', '2012', '2010', '2005', '2021', '2010', '2029', '2025', '2014', '2019', '2011', '2013', '2003', '2029', '2030', '2015', '2012']
# 2003
# 	2005
# 	2005
# 	2008
# 	2010
# 	2010
# 	2011
# 	2012
# 	2012
# 	2013
# 	2014
# 	2014
# 	2015
# 	2015
# 	2018
# 	2018
# 	2019
# 	2019
# 	2020
# 	2021
# 	2021
# 	2022
# 	2023
# 	2024
# 	2024
# 	2024
# 	2025
# 	2025
# 	2026
# 	2026
# 	2028
# 	2028
# 	2028
# 	2029
# 	2029
# 	2029
# 	2030
# iyr: ['2026', '1937', '2021', '2021', '1981', '2021', '1979', '1989', '2024', '1971', '2000', '1962', '1935', '1939', '1990', '1970', '1940', '1973', '2022', '2028', '2026', '2009', '2030', '2030', '1999', '1969', '1933', '2023', '2029', '1931', '1951', '1952', '2028', '2030', '1990', '2009', '1972']
# 1931
# 	1933
# 	1935
# 	1937
# 	1939
# 	1940
# 	1951
# 	1952
# 	1962
# 	1969
# 	1970
# 	1971
# 	1972
# 	1973
# 	1979
# 	1981
# 	1989
# 	1990
# 	1990
# 	1999
# 	2000
# 	2009
# 	2009
# 	2021
# 	2021
# 	2021
# 	2022
# 	2023
# 	2024
# 	2026
# 	2026
# 	2028
# 	2028
# 	2029
# 	2030
# 	2030
# 	2030
# eyr: ['2034', '2036', '1981', '2039', '2031', '1952', '2039', '2031', '1936', '2009', '2036', '1985', '2035', '1927', '2032', '2031', '2033', '2033', '2037', '2032', '2038', '2034', '1972', '2032', '1920', '1932', '2038', '1931', '2039', '1971', '1931', '2031', '2033', '2035', '2040', '2036']
# 1920
# 	1927
# 	1931
# 	1931
# 	1932
# 	1936
# 	1952
# 	1971
# 	1972
# 	1981
# 	1985
# 	2009
# 	2031
# 	2031
# 	2031
# 	2031
# 	2032
# 	2032
# 	2032
# 	2033
# 	2033
# 	2033
# 	2034
# 	2034
# 	2035
# 	2035
# 	2036
# 	2036
# 	2036
# 	2037
# 	2038
# 	2038
# 	2039
# 	2039
# 	2039
# 	2040
# hgt: ['61cm', '61cm', '190in', '192in', '170in', '176in', '187in', '170in', '61cm', '71cm', '66cm', '189in', '181in', '192in', '156in', '74cm', '164in', '150in', '76cm', '184in', '61cm', '158in']
# 150in
# 	156in
# 	158in
# 	164in
# 	170in
# 	170in
# 	176in
# 	181in
# 	184in
# 	187in
# 	189in
# 	190in
# 	192in
# 	192in
# 	61cm
# 	61cm
# 	61cm
# 	61cm
# 	66cm
# 	71cm
# 	74cm
# 	76cm
# hcl: []
#
# ecl: []
#
# pid: []
#
# cid: []
#
# Num valid passports Part2: 185
